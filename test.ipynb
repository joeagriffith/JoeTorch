# %%
import torch

x = torch.nn.LayerNorm
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 import torch
#       3 x = torch.nn.LayerNorm
# ----> 4 isinstance(x, callable)
#
# TypeError: isinstance() arg 2 must be a type, a tuple of types, or a union

# %%
dtype = torch.bfloat16
dtype
# Out:
# torch.bfloat16

# %%
from optim import *

base = 0.1
end = 0.01
T = 100
warmup = 10
flat = 10
milestones = [30, 50, 70]
gamma = 0.1

cosine = cosine_schedule(base, end, T, warmup, flat)
step = step_schedule(base, T, milestones, gamma, warmup, flat)
flat = flat_schedule(base, T, warmup, flat)


import matplotlib.pyplot as plt
plt.plot(cosine, label='cosine')
plt.plot(step, label='step')
plt.plot(flat, label='flat')
plt.legend()
plt.show()

# %%
from datasets.mnist import MNIST

train_set = MNIST(root='../../datasets', split='train', val_ratio=0.1, normalize=True, transform=None, dtype='float32', device='cpu', download=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 from datasets.mnist import MNIST
# ----> 3 train_set = MNIST(root='../../datasets', split='train', val_ratio=0.1, normalize=True, transform=None, dtype='float32', device='cpu', download=True)
#
# File ~/projects/JoeTorch/datasets/mnist.py:30, in MNIST(root, split, val_ratio, normalize, transform, dtype, device, download)
#      28     n_train = int(len(dataset) * (1 - val_ratio))
#      29     dataset = torch.utils.data.Subset(dataset, range(0, n_train))
# ---> 30     dataset = PreloadedDataset.from_dataset(dataset, transform, device, use_tqdm=True)
#      32 elif split == 'val':
#      33     # Build val dataset
#      34     n_val = len(dataset) * val_ratio
#
# File ~/projects/JoeTorch/datasets/dataset.py:69, in PreloadedDataset.from_dataset(dataset, transform, device, use_tqdm)
# ...
